# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
data=pd.read_csv('laptop_prices.csv')
data.head()
# Out:
#   Company      Product   TypeName  Inches  Ram     OS  Weight  Price_euros  \
# 0   Apple  MacBook Pro  Ultrabook    13.3    8  macOS    1.37      1339.69
# 1   Apple  Macbook Air  Ultrabook    13.3    8  macOS    1.34       898.94
# 2      HP       250 G6   Notebook    15.6    8  No OS    1.86       575.00
# 3   Apple  MacBook Pro  Ultrabook    15.4   16  macOS    1.83      2537.45
# 4   Apple  MacBook Pro  Ultrabook    13.3    8  macOS    1.37      1803.60
#
#      Screen  ScreenW  ...  RetinaDisplay CPU_company CPU_freq      CPU_model  \
# 0  Standard     2560  ...            Yes       Intel      2.3        Core i5
# 1  Standard     1440  ...             No       Intel      1.8        Core i5
# 2   Full HD     1920  ...             No       Intel      2.5  Core i5 7200U
# 3  Standard     2880  ...            Yes       Intel      2.7        Core i7
# 4  Standard     2560  ...            Yes       Intel      3.1        Core i5
#
# ...

# %%
data.shape
# Out:
# (1275, 23)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1275 entries, 0 to 1274
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Company               1275 non-null   object
#  1   Product               1275 non-null   object
#  2   TypeName              1275 non-null   object
#  3   Inches                1275 non-null   float64
#  4   Ram                   1275 non-null   int64
#  5   OS                    1275 non-null   object
#  6   Weight                1275 non-null   float64
#  7   Price_euros           1275 non-null   float64
#  8   Screen                1275 non-null   object
#  9   ScreenW               1275 non-null   int64
#  10  ScreenH               1275 non-null   int64
#  11  Touchscreen           1275 non-null   object
#  12  IPSpanel              1275 non-null   object
#  13  RetinaDisplay         1275 non-null   object
#  14  CPU_company           1275 non-null   object
# ...

# %%
data.isnull().sum()
# Out:
# Company                 0
# Product                 0
# TypeName                0
# Inches                  0
# Ram                     0
# OS                      0
# Weight                  0
# Price_euros             0
# Screen                  0
# ScreenW                 0
# ScreenH                 0
# Touchscreen             0
# IPSpanel                0
# RetinaDisplay           0
# CPU_company             0
# CPU_freq                0
# CPU_model               0
# PrimaryStorage          0
# SecondaryStorage        0
# PrimaryStorageType      0
# SecondaryStorageType    0
# GPU_company             0
# GPU_model               0
# dtype: int64

# %%
data.describe()
# Out:
#             Inches          Ram       Weight  Price_euros      ScreenW  \
# count  1275.000000  1275.000000  1275.000000  1275.000000  1275.000000
# mean     15.022902     8.440784     2.040525  1134.969059  1900.043922
# std       1.429470     5.097809     0.669196   700.752504   493.346186
# min      10.100000     2.000000     0.690000   174.000000  1366.000000
# 25%      14.000000     4.000000     1.500000   609.000000  1920.000000
# 50%      15.600000     8.000000     2.040000   989.000000  1920.000000
# 75%      15.600000     8.000000     2.310000  1496.500000  1920.000000
# max      18.400000    64.000000     4.700000  6099.000000  3840.000000
#
#            ScreenH     CPU_freq  PrimaryStorage  SecondaryStorage
# count  1275.000000  1275.000000     1275.000000       1275.000000
# mean   1073.904314     2.302980      444.517647        176.069020
# std     283.883940     0.503846      365.537726        415.960655
# ...

# %%
data['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
data['OS'].value_counts().plot(kind = 'bar' , x = data['OS'])
# Out:
# <Axes: xlabel='OS'>

# %%
    data['Touchscreen'].value_counts().plot(kind = 'pie', autopct =
'%.2f%%' , title = 'TouchScreen')
# Out:
# <Axes: title={'center': 'TouchScreen'}, ylabel='count'>

# %%
data['Ram'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
data['CPU_company'].value_counts().plot(kind = 'pie' , autopct
= '%.2f%%', title = 'CPU_Company')
# Out:
# <Axes: title={'center': 'CPU_Company'}, ylabel='count'>

# %%
data['GPU_company'].value_counts().plot(kind = 'pie' , autopct
= '%.2f%%', title = 'GPU_Company')
# Out:
# <Axes: title={'center': 'GPU_Company'}, ylabel='count'>

# %%
data['IPSpanel'].value_counts().plot(kind = 'pie' , autopct =
'%.f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['Inches'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Inches'>

# %%
data['PrimaryStorageType'].value_counts().plot(kind = 'pie' ,
autopct = '%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['Screen'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Screen'>

# %%
data['SecondaryStorageType'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='SecondaryStorageType'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1275 entries, 0 to 1274
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Company               1275 non-null   object
#  1   Product               1275 non-null   object
#  2   TypeName              1275 non-null   object
#  3   Inches                1275 non-null   float64
#  4   Ram                   1275 non-null   int64
#  5   OS                    1275 non-null   object
#  6   Weight                1275 non-null   float64
#  7   Price_euros           1275 non-null   float64
#  8   Screen                1275 non-null   object
#  9   ScreenW               1275 non-null   int64
#  10  ScreenH               1275 non-null   int64
#  11  Touchscreen           1275 non-null   object
#  12  IPSpanel              1275 non-null   object
#  13  RetinaDisplay         1275 non-null   object
#  14  CPU_company           1275 non-null   object
# ...

# %%
plt.figure(figsize = (10,8))
sns.boxplot(x = data['OS'], y= data['Price_euros'],hue=data['OS'], palette='Set1', dodge=False)
plt.title('OS VS CPU_freqency')
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.barplot(x = data['Touchscreen'], y= data['Price_euros'] ,
hue = data['Screen'])
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.barplot(x = data['OS'], y= data['Price_euros'] ,
hue = data['Touchscreen'])
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.barplot(x = data['PrimaryStorage'], y= data['Price_euros']
, hue = data['SecondaryStorage'])
plt.show()

# %%
plt.figure(figsize = (10,8))
sns.barplot(x = data['RetinaDisplay'], y= data['Price_euros'],
hue = data['PrimaryStorage'])
plt.show()

# %%
sns.scatterplot(data = data , x= data['CPU_freq'], y =
data['Ram'], hue = data['OS'])
# Out:
# <Axes: xlabel='CPU_freq', ylabel='Ram'>

# %%
sns.scatterplot(data = data , x= data['CPU_freq'], y =
data['Ram'], hue = data['OS'])
# Out:
# <Axes: xlabel='CPU_freq', ylabel='Ram'>

# %%
laptop_df = pd.read_csv("laptop_prices.csv")

# Print column names
print(laptop_df.columns)
# Out:
# Index(['Company', 'Product', 'TypeName', 'Inches', 'Ram', 'OS', 'Weight',
#        'Price_euros', 'Screen', 'ScreenW', 'ScreenH', 'Touchscreen',
#        'IPSpanel', 'RetinaDisplay', 'CPU_company', 'CPU_freq', 'CPU_model',
#        'PrimaryStorage', 'SecondaryStorage', 'PrimaryStorageType',
#        'SecondaryStorageType', 'GPU_company', 'GPU_model'],
#       dtype='object')

# %%
import pandas as pd
import joblib
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder

# Load dataset
file_path = "laptop_prices.csv"
df = pd.read_csv(file_path)

# Selecting necessary features
features = ["Company", "OS", "CPU_company", "PrimaryStorageType", "SecondaryStorageType", "GPU_company",
            "Inches", "Ram", "Weight", "ScreenW", "ScreenH", "CPU_freq", "PrimaryStorage", "SecondaryStorage"]
target = "Price_euros"

df = df[features + [target]].dropna()

# Encoding categorical features
label_encoders = {}
for col in ["Company", "OS", "CPU_company", "PrimaryStorageType", "SecondaryStorageType", "GPU_company"]:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# Splitting dataset
X = df[features]
y = df[target]

# Training model
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X, y)

# Save model and encoders
joblib.dump(model, "laptop_price_model.joblib")
joblib.dump(label_encoders, "label_encoders.joblib")

print("Model training complete and saved.")
# Out:
# Model training complete and saved.

# %%
import joblib

try:
    model = joblib.load("laptop_price_model.joblib")
    label_encoders = joblib.load("label_encoders.joblib")
    print("Model and encoders loaded successfully.")
except FileNotFoundError:
    print("Error: Model files not found. Run the training script first.")
# Out:
# Model and encoders loaded successfully.

# %%
import pandas as pd
import joblib

# Load model and encoders
model = joblib.load("laptop_price_model.joblib")
label_encoders = joblib.load("label_encoders.joblib")

# Function to get valid user input
def get_valid_input(prompt, valid_options=None, value_range=None, dtype=str):
    while True:
        if valid_options:
            print(f"Available options: {', '.join(valid_options)}")  # Show available choices
        
        user_input = input(prompt).strip()  # Remove extra spaces
        
        if dtype == str:
            # Match user input with available options (case-insensitive)
            if valid_options:
                matched_option = next((opt for opt in valid_options if opt.lower() == user_input.lower()), None)
                if matched_option:
                    user_input = matched_option
                else:
                    print(f"Invalid choice. Choose from: {', '.join(valid_options)}")
                    continue
        
        try:
            if dtype in [int, float]:
                user_input = dtype(user_input)
                if value_range and not (value_range[0] <= user_input <= value_range[1]):
                    print(f"Please enter a value between {value_range[0]} and {value_range[1]}.")
                    continue
            return user_input
        except ValueError:
            print(f"Please enter a valid {dtype.__name__}.")

# Feature details (categorical values and numeric ranges)
feature_options = {
    "Company": list(label_encoders["Company"].classes_),
    "OS": list(label_encoders["OS"].classes_),
    "CPU_company": list(label_encoders["CPU_company"].classes_),
    "PrimaryStorageType": list(label_encoders["PrimaryStorageType"].classes_),
    "SecondaryStorageType": list(label_encoders["SecondaryStorageType"].classes_),
    "GPU_company": list(label_encoders["GPU_company"].classes_)
}

numeric_ranges = {
    "Inches": (10, 20),
    "Ram": (2, 64),
    "Weight": (0.5, 5),
    "ScreenW": (800, 3840),
    "ScreenH": (600, 2160),
    "CPU_freq": (1.0, 5.0),
    "PrimaryStorage": (128, 8192),
    "SecondaryStorage": (0, 8192)
}

# Get user input
user_data = {}
for feature, options in feature_options.items():
    user_data[feature] = get_valid_input(f"Enter {feature}: ", valid_options=options, dtype=str)

for feature, (min_val, max_val) in numeric_ranges.items():
    user_data[feature] = get_valid_input(f"Enter {feature} ({min_val}-{max_val}): ", value_range=(min_val, max_val), dtype=float if feature == "Weight" else int)

# Convert user input to DataFrame
input_df = pd.DataFrame([user_data])

# Encode categorical variables
for col in feature_options.keys():
    input_df[col] = label_encoders[col].transform(input_df[col])

# Predict price
predicted_price = model.predict(input_df)[0]
print(f"Predicted Laptop Price: €{predicted_price:.2f}")
# Out:
# Available options: Acer, Apple, Asus, Chuwi, Dell, Fujitsu, Google, HP, Huawei, LG, Lenovo, MSI, Mediacom, Microsoft, Razer, Samsung, Toshiba, Vero, Xiaomi
# Enter Company:  acer
# Available options: Android, Chrome OS, Linux, Mac OS X, No OS, Windows 10, Windows 10 S, Windows 7, macOS
# Enter OS:  windows 10
# Available options: AMD, Intel, Samsung
# Enter CPU_company:  amd
# Available options: Flash Storage, HDD, Hybrid, SSD
# Enter PrimaryStorageType:  ssd
# Available options: HDD, Hybrid, No, SSD
# Enter SecondaryStorageType:  hdd
# Available options: AMD, ARM, Intel, Nvidia
# Enter GPU_company:  intel
# Enter Inches (10-20):  15.6
# Please enter a valid int.
# Enter Inches (10-20):  15
# Enter Ram (2-64):  16
# Enter Weight (0.5-5):  1.3
# Enter ScreenW (800-3840):  1200
# Enter ScreenH (600-2160):  1200
# Enter CPU_freq (1.0-5.0):  3.5
# Please enter a valid int.
# Enter CPU_freq (1.0-5.0):  4
# Enter PrimaryStorage (128-8192):  256
# Enter SecondaryStorage (0-8192):  512
# ...

# %%
from PIL import Image, ImageDraw, ImageFont

def generate_price_image(user_input_text, predicted_price, output_filename="laptop_price.png"):
    # Create an image
    img = Image.new("RGB", (800, 600), color="white")
    draw = ImageDraw.Draw(img)

    # Load font (default system font)
    try:
        font = ImageFont.truetype("arial.ttf", 20)
    except:
        font = ImageFont.load_default()

    # Prepare text
    text = f"{user_input_text}\nPredicted Laptop Price: €{predicted_price:.2f}"
    
    # Draw text
    draw.multiline_text((20, 20), text, fill="black", font=font)

    # Save the image
    img.save(output_filename)
    print(f"Image saved as {output_filename}")

# Example usage
user_input_text = """
Available options: Acer, Apple, Asus, Chuwi, Dell, Fujitsu, Google, HP, Huawei, LG, Lenovo, MSI, Mediacom, Microsoft, Razer, Samsung, Toshiba, Vero, Xiaomi
Enter Company: Acer
Enter OS: Windows 10
Enter CPU_company: AMD
Enter PrimaryStorageType: SSD
Enter SecondaryStorageType: HDD
Enter GPU_company: Intel
Enter Inches: 15
Enter Ram: 16
Enter Weight: 1.3
Enter ScreenW: 1200
Enter ScreenH: 1200
Enter CPU_freq: 4
Enter PrimaryStorage: 256
Enter SecondaryStorage: 512
"""

predicted_price = 2191.04
generate_price_image(user_input_text, predicted_price)
# Out:
# Image saved as laptop_price.png
